# %%
# %matplotlib inline
from __future__ import print_function
from __future__ import division

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# # Load dataset

# %%
# load the provided data
X = pd.read_csv('../data/01_raw/dengue_features_train.csv',
                             index_col=[0,1,2])

y = pd.read_csv('../data/01_raw/dengue_labels_train.csv',
                           index_col=[0,1,2])

# %%
print('features: ', X.shape)
print('labels  : ', y.shape)
# Out:
# features:  (1456, 21)
# labels  :  (1456, 1)

# %%
X
# Out:
#                      week_start_date   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# city year weekofyear
# sj   1990 18              1990-04-30  0.122600  0.103725  0.198483  0.177617
#           19              1990-05-07  0.169900  0.142175  0.162357  0.155486
#           20              1990-05-14  0.032250  0.172967  0.157200  0.170843
#           21              1990-05-21  0.128633  0.245067  0.227557  0.235886
#           22              1990-05-28  0.196200  0.262200  0.251200  0.247340
# ...                              ...       ...       ...       ...       ...
# iq   2010 21              2010-05-28  0.342750  0.318900  0.256343  0.292514
#           22              2010-06-04  0.160157  0.160371  0.136043  0.225657
#           23              2010-06-11  0.247057  0.146057  0.250357  0.233714
#           24              2010-06-18  0.333914  0.245771  0.278886  0.325486
#           25              2010-06-25  0.298186  0.232971  0.274214  0.315757
#
# ...

# %%
# Remove `week_start_date` string.
X = X.drop('week_start_date', axis=1)

# %%
X
# Out:
#                        ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# city year weekofyear
# sj   1990 18          0.122600  0.103725  0.198483  0.177617
#           19          0.169900  0.142175  0.162357  0.155486
#           20          0.032250  0.172967  0.157200  0.170843
#           21          0.128633  0.245067  0.227557  0.235886
#           22          0.196200  0.262200  0.251200  0.247340
# ...                        ...       ...       ...       ...
# iq   2010 21          0.342750  0.318900  0.256343  0.292514
#           22          0.160157  0.160371  0.136043  0.225657
#           23          0.247057  0.146057  0.250357  0.233714
#           24          0.333914  0.245771  0.278886  0.325486
#           25          0.298186  0.232971  0.274214  0.315757
#
#                       precipitation_amt_mm  reanalysis_air_temp_k  \
# city year weekofyear
# sj   1990 18                         12.42             297.572857
# ...

# %% [markdown]
# # Data columns analysis

# %%
# Null check
pd.isnull(X).any()
# Out:
# ndvi_ne                                  True
# ndvi_nw                                  True
# ndvi_se                                  True
# ndvi_sw                                  True
# precipitation_amt_mm                     True
# reanalysis_air_temp_k                    True
# reanalysis_avg_temp_k                    True
# reanalysis_dew_point_temp_k              True
# reanalysis_max_air_temp_k                True
# reanalysis_min_air_temp_k                True
# reanalysis_precip_amt_kg_per_m2          True
# reanalysis_relative_humidity_percent     True
# reanalysis_sat_precip_amt_mm             True
# reanalysis_specific_humidity_g_per_kg    True
# reanalysis_tdtr_k                        True
# station_avg_temp_c                       True
# station_diur_temp_rng_c                  True
# station_max_temp_c                       True
# station_min_temp_c                       True
# station_precip_mm                        True
# dtype: bool

# %%
X.fillna(method='ffill', inplace=True)
# Out:
# /var/folders/ky/_ck3d0fs7b16dc9vvm30qjnh0000gn/T/ipykernel_30326/2672030822.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   X.fillna(method='ffill', inplace=True)

# %%
pd.isnull(X_train).any()
# Out:
# ndvi_ne                                  False
# ndvi_nw                                  False
# ndvi_se                                  False
# ndvi_sw                                  False
# precipitation_amt_mm                     False
# reanalysis_air_temp_k                    False
# reanalysis_avg_temp_k                    False
# reanalysis_dew_point_temp_k              False
# reanalysis_max_air_temp_k                False
# reanalysis_min_air_temp_k                False
# reanalysis_precip_amt_kg_per_m2          False
# reanalysis_relative_humidity_percent     False
# reanalysis_sat_precip_amt_mm             False
# reanalysis_specific_humidity_g_per_kg    False
# reanalysis_tdtr_k                        False
# station_avg_temp_c                       False
# station_diur_temp_rng_c                  False
# station_max_temp_c                       False
# station_min_temp_c                       False
# station_precip_mm                        False
# dtype: bool

# %%
print(X.shape)
print(y.shape)
# Out:
# (1456, 20)
# (1456, 1)

# %%
#train_validation_split
X_train, X_val, y_train, y_val = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
# Create and train model
rf = RandomForestRegressor(n_estimators = 200, max_depth = 5, random_state = 18)
rf.fit(X_train, y_train)


# Predict on test data
prediction = rf.predict(X_val)
# Compute mean absolute error
mae_val = mean_absolute_error(y_val, prediction)
# Print results
print(mae_val)
# Out:
# /opt/miniconda3/envs/dsr-b38/lib/python3.12/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 18.68849065499948

# %%
y_train.mean()
# Out:
# total_cases    23.529931
# dtype: float64

# %%
X_test = pd.read_csv('../data/01_raw/dengue_features_test.csv',
                             index_col=[0,1,2])
# Remove `week_start_date` string.
X_test = X_test.drop('week_start_date', axis=1)
X_test.fillna(method='ffill', inplace=True)

y_test = rf.predict(X_test)
# Out:
# /var/folders/ky/_ck3d0fs7b16dc9vvm30qjnh0000gn/T/ipykernel_30326/2319890867.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   X_test.fillna(method='ffill', inplace=True)

# %%
y_test.shape
# Out:
# (416,)

# %%
# Submission

df_sub_format = pd.read_csv("../data/01_raw/submission_format.csv")
city = df_sub_format.iloc[:, 0].values
year = df_sub_format.iloc[:, 1].values
weekofyear = df_sub_format.iloc[:, 2].values

df_submission = pd.DataFrame({"city" : city, "year" : year, "weekofyear" : weekofyear, "total_cases": y_test.astype(int)})
df_submission.to_csv("../data/submission.csv", index=False)

# %%
df_submission
# Out:
#     city  year  weekofyear  total_cases
# 0     sj  2008          18           16
# 1     sj  2008          19           15
# 2     sj  2008          20           12
# 3     sj  2008          21           21
# 4     sj  2008          22           34
# ..   ...   ...         ...          ...
# 411   iq  2013          22            6
# 412   iq  2013          23            3
# 413   iq  2013          24            3
# 414   iq  2013          25            4
# 415   iq  2013          26            3
#
# [416 rows x 4 columns]
